# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment

# %%
import tweepy
import pandas as pd
from IPython.display import display
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'NfWqeGFH0AJ8VrUNGuOTQ1Qdf'
consumer_secret = 'Bxux7uqA4uC9TeoEtAhJ7DAR1V2BkoGC1ypKM22DtIFoAkCM4J'
access_token = '134961167-1CPt4kSAKJy6HmbMCvdwmw7cqH1aHIfQo9Uk7GiJ'
access_token_secret = 'EbXJA4uDrc8C2FgAeEg5Ele98AGQ3IcU3cCskfg9FoEx8'

# %%
#cleaning text
import re
#Test
a=data['Tweets'][0]
#display(data['Tweets'][0:10])
print(" ".join(re.sub("@[\w]+"," ",a).split()))


def tweet_cleaner(tweet):
    return " ".join(re.sub("(@[\w]+)|([^0-9a-zA-Z \t])","",tweet).split())
# Out:
# I rly like the pro controller for MM2 Id say its comparable t httpstcoPAJrlmaLlo

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Xbox', count=200)


data = pd.DataFrame(data=[tweet_cleaner(tweet.text) for tweet in tweets], columns=['Tweets'])

display(data.head(10))


#print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT bruh jose be pissing me tf off when he dont...
# 1                         Come to Xbox or switch pls
# 2  Kid is so fucking annoying STOP FUCKING BUGGIN...
# 3             derGrobi beleidigt mtter auf xbox live
# 4   tenho ate dia 2008 p cancelar a xbox live gracas
# 5  Now I enjoy the Playstation and their excl htt...
# 6  RT Project Cars 2 Deluxe por 80 conto no Xbox ...
# 7                                               Xbox
# 8  RT Xbox XO Xbox s ad xbo ultimate marketing ri...
# 9  RT SPECIAL MUT 20 GIVEAWAY2 x Xbox One Madden ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\thond\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []
listz = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(50))
# Out:
#                                                Tweets  \
# 0   RT bruh jose be pissing me tf off when he dont...
# 1                          Come to Xbox or switch pls
# 2   Kid is so fucking annoying STOP FUCKING BUGGIN...
# 3              derGrobi beleidigt mtter auf xbox live
# 4    tenho ate dia 2008 p cancelar a xbox live gracas
# 5   Now I enjoy the Playstation and their excl htt...
# 6   RT Project Cars 2 Deluxe por 80 conto no Xbox ...
# 7                                                Xbox
# 8   RT Xbox XO Xbox s ad xbo ultimate marketing ri...
# 9   RT SPECIAL MUT 20 GIVEAWAY2 x Xbox One Madden ...
# 10  RT We are looking for xbox players that can re...
# 11                 Fix the FPS on Xbox before the cup
# 12  Xbox360Enslaved Odyssey to the WestDL1234XboxO...
# 13  Cant even play my own Xbox man httpstco1haaBDXbnb
# 14  RT GIVEAWAY TIME Another Giveaway from La Fami...
# 15  the only person I ever met on Xbox thats I cou...
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
display(data['polarity'][0].get('pos'))
display(data['polarity'][0])
#data.plot(x=)
# Out:
# 0.059
# {'compound': -0.2732, 'neg': 0.099, 'neu': 0.842, 'pos': 0.059}

# %%
a=data['Tweets'][0]
#''.join(re.sub("@[a-zA-Z]"," ",a).split)

#display(data['Tweets'][0:10])
print(" ".join(re.sub("@[\w]+"," ",a).split()))
# Out:
# Ok Korean prince can u buy me a Xbox one S
